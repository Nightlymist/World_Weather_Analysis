# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
from citipy import citipy
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_url
city_weather = requests.get(city_url).json()
city_weather
city_description = city_weather["weather"][0]["description"]
city_description
# Out:
# 'overcast clouds'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tumpat
# Processing Record 2 of Set 1 | constitucion
# Processing Record 3 of Set 1 | wellington
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | taolanaro
# City not found. skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | manggar
# Processing Record 9 of Set 1 | pietarsaari
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | ripoll
# Processing Record 12 of Set 1 | hobyo
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | umzimvubu
# City not found. skipping...
# Processing Record 15 of Set 1 | alofi
# Processing Record 16 of Set 1 | burnie
# Processing Record 17 of Set 1 | rungata
# City not found. skipping...
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | sofiysk
# City not found. skipping...
# Processing Record 20 of Set 1 | jieshi
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | san pedro
# Processing Record 24 of Set 1 | taoudenni
# Processing Record 25 of Set 1 | mangai
# Processing Record 26 of Set 1 | mahebourg
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | sanchursk
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | annau
# Processing Record 31 of Set 1 | yatou
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | ust-tsilma
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | gobabis
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | atar
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | matara
# Processing Record 44 of Set 1 | dekar
# Processing Record 45 of Set 1 | prince rupert
# Processing Record 46 of Set 1 | grand river south east
# City not found. skipping...
# Processing Record 47 of Set 1 | labytnangi
# Processing Record 48 of Set 1 | djougou
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | deer lake
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | mikhaylovsk
# Processing Record 6 of Set 2 | codrington
# Processing Record 7 of Set 2 | ubon ratchathani
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | husavik
# Processing Record 10 of Set 2 | zhaoqing
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | victoria
# Processing Record 13 of Set 2 | marcona
# City not found. skipping...
# Processing Record 14 of Set 2 | nanortalik
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | hope
# Processing Record 18 of Set 2 | pisco
# Processing Record 19 of Set 2 | camopi
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | soloneshnoye
# Processing Record 23 of Set 2 | souillac
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | taltal
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | camacha
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | jaisalmer
# Processing Record 31 of Set 2 | santa cruz del norte
# Processing Record 32 of Set 2 | damghan
# Processing Record 33 of Set 2 | paamiut
# Processing Record 34 of Set 2 | saleaula
# City not found. skipping...
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | mhasla
# Processing Record 38 of Set 2 | jinsha
# Processing Record 39 of Set 2 | baykalsk
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | azimur
# City not found. skipping...
# Processing Record 42 of Set 2 | tiznit
# Processing Record 43 of Set 2 | avera
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | attawapiskat
# City not found. skipping...
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | hovd
# Processing Record 49 of Set 2 | seondha
# Processing Record 50 of Set 2 | kamina
# Processing Record 1 of Set 3 | hongjiang
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | samaipata
# Processing Record 4 of Set 3 | mys shmidta
# City not found. skipping...
# Processing Record 5 of Set 3 | korla
# Processing Record 6 of Set 3 | parana
# Processing Record 7 of Set 3 | baiao
# Processing Record 8 of Set 3 | north bend
# Processing Record 9 of Set 3 | progreso
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | mandalgovi
# Processing Record 13 of Set 3 | bolungarvik
# City not found. skipping...
# Processing Record 14 of Set 3 | palabuhanratu
# City not found. skipping...
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | cayenne
# Processing Record 18 of Set 3 | saint-pierre
# Processing Record 19 of Set 3 | nishihara
# Processing Record 20 of Set 3 | lompoc
# Processing Record 21 of Set 3 | tura
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | arlit
# Processing Record 24 of Set 3 | talcahuano
# Processing Record 25 of Set 3 | deputatskiy
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | russell
# Processing Record 28 of Set 3 | tongliao
# Processing Record 29 of Set 3 | yoichi
# Processing Record 30 of Set 3 | zaliznychne
# Processing Record 31 of Set 3 | alausi
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | amderma
# City not found. skipping...
# Processing Record 35 of Set 3 | bereda
# Processing Record 36 of Set 3 | shimoda
# Processing Record 37 of Set 3 | penarth
# Processing Record 38 of Set 3 | barentsburg
# City not found. skipping...
# Processing Record 39 of Set 3 | bell ville
# Processing Record 40 of Set 3 | urla
# Processing Record 41 of Set 3 | huadian
# Processing Record 42 of Set 3 | goderich
# Processing Record 43 of Set 3 | mehamn
# Processing Record 44 of Set 3 | madera
# Processing Record 45 of Set 3 | mukhen
# Processing Record 46 of Set 3 | ingleside
# Processing Record 47 of Set 3 | gizo
# Processing Record 48 of Set 3 | bull savanna
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | gondanglegi
# Processing Record 1 of Set 4 | khutar
# Processing Record 2 of Set 4 | rosarito
# Processing Record 3 of Set 4 | port hardy
# Processing Record 4 of Set 4 | keetmanshoop
# Processing Record 5 of Set 4 | severo-kurilsk
# Processing Record 6 of Set 4 | laguna
# Processing Record 7 of Set 4 | makakilo city
# Processing Record 8 of Set 4 | upata
# Processing Record 9 of Set 4 | jazzin
# City not found. skipping...
# Processing Record 10 of Set 4 | kerrabe
# City not found. skipping...
# Processing Record 11 of Set 4 | loreto
# Processing Record 12 of Set 4 | caravelas
# Processing Record 13 of Set 4 | bluff
# Processing Record 14 of Set 4 | kavaratti
# Processing Record 15 of Set 4 | menongue
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | dunedin
# Processing Record 18 of Set 4 | tarija
# Processing Record 19 of Set 4 | lakes entrance
# Processing Record 20 of Set 4 | dali
# Processing Record 21 of Set 4 | labuhan
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | aklavik
# Processing Record 24 of Set 4 | christchurch
# Processing Record 25 of Set 4 | belushya guba
# City not found. skipping...
# Processing Record 26 of Set 4 | amazar
# Processing Record 27 of Set 4 | nizhniy kuranakh
# Processing Record 28 of Set 4 | manaure
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | acapulco
# Processing Record 31 of Set 4 | anisoc
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | mwinilunga
# Processing Record 34 of Set 4 | turukhansk
# Processing Record 35 of Set 4 | atbasar
# Processing Record 36 of Set 4 | komsomolskiy
# Processing Record 37 of Set 4 | moindou
# Processing Record 38 of Set 4 | erdenet
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | varkkallai
# Processing Record 41 of Set 4 | mount gambier
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | grandview
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | aleksinac
# Processing Record 46 of Set 4 | aviles
# Processing Record 47 of Set 4 | aflu
# City not found. skipping...
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | fortuna
# Processing Record 50 of Set 4 | tooele
# Processing Record 1 of Set 5 | ahipara
# Processing Record 2 of Set 5 | albany
# Processing Record 3 of Set 5 | praia da vitoria
# Processing Record 4 of Set 5 | huaihua
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | clyde
# Processing Record 7 of Set 5 | killybegs
# Processing Record 8 of Set 5 | maloy
# Processing Record 9 of Set 5 | iqaluit
# Processing Record 10 of Set 5 | quelimane
# Processing Record 11 of Set 5 | meulaboh
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | la rioja
# Processing Record 14 of Set 5 | ahuimanu
# Processing Record 15 of Set 5 | lorengau
# Processing Record 16 of Set 5 | coihaique
# Processing Record 17 of Set 5 | stege
# Processing Record 18 of Set 5 | vaitupu
# City not found. skipping...
# Processing Record 19 of Set 5 | sakakah
# Processing Record 20 of Set 5 | ngukurr
# City not found. skipping...
# Processing Record 21 of Set 5 | marsa matruh
# Processing Record 22 of Set 5 | muravlenko
# Processing Record 23 of Set 5 | tumannyy
# City not found. skipping...
# Processing Record 24 of Set 5 | tsihombe
# City not found. skipping...
# Processing Record 25 of Set 5 | sorland
# Processing Record 26 of Set 5 | bodden town
# Processing Record 27 of Set 5 | rubizhne
# Processing Record 28 of Set 5 | crossville
# Processing Record 29 of Set 5 | lamar
# Processing Record 30 of Set 5 | yar-sale
# Processing Record 31 of Set 5 | gigmoto
# Processing Record 32 of Set 5 | salinas
# Processing Record 33 of Set 5 | san cristobal
# Processing Record 34 of Set 5 | trairi
# Processing Record 35 of Set 5 | bur gabo
# City not found. skipping...
# Processing Record 36 of Set 5 | touros
# Processing Record 37 of Set 5 | kumba
# Processing Record 38 of Set 5 | kameshkovo
# Processing Record 39 of Set 5 | kamaishi
# Processing Record 40 of Set 5 | myitkyina
# Processing Record 41 of Set 5 | aykhal
# Processing Record 42 of Set 5 | rio verde de mato grosso
# Processing Record 43 of Set 5 | celestun
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | leningradskiy
# Processing Record 46 of Set 5 | hurghada
# Processing Record 47 of Set 5 | mayo
# Processing Record 48 of Set 5 | srednekolymsk
# Processing Record 49 of Set 5 | lenoir
# Processing Record 50 of Set 5 | shchelyayur
# City not found. skipping...
# Processing Record 1 of Set 6 | kudahuvadhoo
# Processing Record 2 of Set 6 | dingle
# Processing Record 3 of Set 6 | mount isa
# Processing Record 4 of Set 6 | broken hill
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | savelugu
# Processing Record 7 of Set 6 | sanchor
# Processing Record 8 of Set 6 | saint george
# Processing Record 9 of Set 6 | isangel
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | nicoya
# Processing Record 12 of Set 6 | narsaq
# Processing Record 13 of Set 6 | baghdad
# Processing Record 14 of Set 6 | ponta do sol
# Processing Record 15 of Set 6 | krasnyy chikoy
# Processing Record 16 of Set 6 | san ramon
# Processing Record 17 of Set 6 | boca do acre
# Processing Record 18 of Set 6 | port macquarie
# Processing Record 19 of Set 6 | kazalinsk
# City not found. skipping...
# Processing Record 20 of Set 6 | moundsville
# Processing Record 21 of Set 6 | hihifo
# City not found. skipping...
# Processing Record 22 of Set 6 | zheleznodorozhnyy
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | inuvik
# Processing Record 25 of Set 6 | eydhafushi
# Processing Record 26 of Set 6 | arman
# Processing Record 27 of Set 6 | sumter
# Processing Record 28 of Set 6 | micheweni
# Processing Record 29 of Set 6 | kamenskoye
# City not found. skipping...
# Processing Record 30 of Set 6 | longyearbyen
# Processing Record 31 of Set 6 | buala
# Processing Record 32 of Set 6 | hualmay
# Processing Record 33 of Set 6 | coos bay
# Processing Record 34 of Set 6 | nhulunbuy
# Processing Record 35 of Set 6 | faya
# Processing Record 36 of Set 6 | chuy
# Processing Record 37 of Set 6 | bredasdorp
# Processing Record 38 of Set 6 | klaksvik
# Processing Record 39 of Set 6 | hoi an
# Processing Record 40 of Set 6 | petatlan
# Processing Record 41 of Set 6 | maracas
# Processing Record 42 of Set 6 | dawei
# Processing Record 43 of Set 6 | bubaque
# Processing Record 44 of Set 6 | ongole
# Processing Record 45 of Set 6 | soller
# Processing Record 46 of Set 6 | kaitangata
# Processing Record 47 of Set 6 | ko samui
# Processing Record 48 of Set 6 | diffa
# Processing Record 49 of Set 6 | shaki
# Processing Record 50 of Set 6 | poya
# Processing Record 1 of Set 7 | novyy svit
# Processing Record 2 of Set 7 | sumbe
# Processing Record 3 of Set 7 | yeppoon
# Processing Record 4 of Set 7 | nangwa
# Processing Record 5 of Set 7 | olafsvik
# Processing Record 6 of Set 7 | necochea
# Processing Record 7 of Set 7 | vestmannaeyjar
# Processing Record 8 of Set 7 | pamulang
# Processing Record 9 of Set 7 | carlsbad
# Processing Record 10 of Set 7 | talnakh
# Processing Record 11 of Set 7 | sao borja
# Processing Record 12 of Set 7 | rivadavia
# Processing Record 13 of Set 7 | flin flon
# Processing Record 14 of Set 7 | kolokani
# Processing Record 15 of Set 7 | grand gaube
# Processing Record 16 of Set 7 | panaba
# Processing Record 17 of Set 7 | piotrkow trybunalski
# Processing Record 18 of Set 7 | burns lake
# Processing Record 19 of Set 7 | comodoro rivadavia
# Processing Record 20 of Set 7 | cheremukhovo
# Processing Record 21 of Set 7 | denpasar
# Processing Record 22 of Set 7 | loukhi
# Processing Record 23 of Set 7 | khatanga
# Processing Record 24 of Set 7 | port-gentil
# Processing Record 25 of Set 7 | fuyang
# Processing Record 26 of Set 7 | kailasahar
# City not found. skipping...
# Processing Record 27 of Set 7 | sumbawa
# City not found. skipping...
# Processing Record 28 of Set 7 | jahrom
# City not found. skipping...
# Processing Record 29 of Set 7 | mecca
# Processing Record 30 of Set 7 | tanabe
# Processing Record 31 of Set 7 | evensk
# Processing Record 32 of Set 7 | thinadhoo
# Processing Record 33 of Set 7 | torbat-e jam
# Processing Record 34 of Set 7 | sangmelima
# Processing Record 35 of Set 7 | hvammstangi
# City not found. skipping...
# Processing Record 36 of Set 7 | sulina
# Processing Record 37 of Set 7 | new norfolk
# Processing Record 38 of Set 7 | east london
# Processing Record 39 of Set 7 | da lat
# Processing Record 40 of Set 7 | te anau
# Processing Record 41 of Set 7 | la asuncion
# Processing Record 42 of Set 7 | itaituba
# Processing Record 43 of Set 7 | chapais
# Processing Record 44 of Set 7 | axim
# Processing Record 45 of Set 7 | yulara
# Processing Record 46 of Set 7 | butte
# Processing Record 47 of Set 7 | altagracia de orituco
# Processing Record 48 of Set 7 | saldanha
# Processing Record 49 of Set 7 | petrivka
# Processing Record 50 of Set 7 | urumqi
# Processing Record 1 of Set 8 | cam pha
# City not found. skipping...
# Processing Record 2 of Set 8 | coahuayana
# Processing Record 3 of Set 8 | warqla
# City not found. skipping...
# Processing Record 4 of Set 8 | lukovetskiy
# Processing Record 5 of Set 8 | roald
# Processing Record 6 of Set 8 | vao
# Processing Record 7 of Set 8 | buraydah
# Processing Record 8 of Set 8 | shupiyan
# Processing Record 9 of Set 8 | vitim
# Processing Record 10 of Set 8 | grevenbroich
# Processing Record 11 of Set 8 | arawa
# Processing Record 12 of Set 8 | kinablangan
# Processing Record 13 of Set 8 | kihei
# Processing Record 14 of Set 8 | bonavista
# Processing Record 15 of Set 8 | noyabrsk
# Processing Record 16 of Set 8 | egvekinot
# Processing Record 17 of Set 8 | mocambique
# City not found. skipping...
# Processing Record 18 of Set 8 | gornyak
# Processing Record 19 of Set 8 | lavrentiya
# Processing Record 20 of Set 8 | lipari
# Processing Record 21 of Set 8 | korsakovo
# Processing Record 22 of Set 8 | kisangani
# Processing Record 23 of Set 8 | moron
# Processing Record 24 of Set 8 | kloulklubed
# Processing Record 25 of Set 8 | cabedelo
# Processing Record 26 of Set 8 | bandarbeyla
# Processing Record 27 of Set 8 | san quintin
# Processing Record 28 of Set 8 | bambous virieux
# Processing Record 29 of Set 8 | havre-saint-pierre
# Processing Record 30 of Set 8 | kharan
# Processing Record 31 of Set 8 | cabo san lucas
# Processing Record 32 of Set 8 | pahrump
# Processing Record 33 of Set 8 | mushie
# Processing Record 34 of Set 8 | sambava
# Processing Record 35 of Set 8 | umm lajj
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | esmeraldas
# Processing Record 38 of Set 8 | bilibino
# Processing Record 39 of Set 8 | markova
# Processing Record 40 of Set 8 | belousovka
# Processing Record 41 of Set 8 | marsh harbour
# Processing Record 42 of Set 8 | pevek
# Processing Record 43 of Set 8 | boende
# Processing Record 44 of Set 8 | naenwa
# City not found. skipping...
# Processing Record 45 of Set 8 | teya
# Processing Record 46 of Set 8 | esperance
# Processing Record 47 of Set 8 | izyum
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | barcelos
# Processing Record 50 of Set 8 | boat of garten
# Processing Record 1 of Set 9 | zhezkazgan
# Processing Record 2 of Set 9 | smithers
# Processing Record 3 of Set 9 | junin
# Processing Record 4 of Set 9 | abiy adi
# City not found. skipping...
# Processing Record 5 of Set 9 | clarksburg
# Processing Record 6 of Set 9 | tezu
# Processing Record 7 of Set 9 | baykit
# Processing Record 8 of Set 9 | farafangana
# Processing Record 9 of Set 9 | andenes
# Processing Record 10 of Set 9 | mercedes
# Processing Record 11 of Set 9 | trelaze
# Processing Record 12 of Set 9 | monastyrshchina
# Processing Record 13 of Set 9 | sisimiut
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | shieli
# Processing Record 16 of Set 9 | turka
# Processing Record 17 of Set 9 | hofn
# Processing Record 18 of Set 9 | tabiauea
# City not found. skipping...
# Processing Record 19 of Set 9 | westport
# Processing Record 20 of Set 9 | ruteng
# Processing Record 21 of Set 9 | yuzhou
# Processing Record 22 of Set 9 | chara
# Processing Record 23 of Set 9 | sainte-marie
# Processing Record 24 of Set 9 | rovaniemi
# Processing Record 25 of Set 9 | lolua
# City not found. skipping...
# Processing Record 26 of Set 9 | lae
# Processing Record 27 of Set 9 | tondano
# Processing Record 28 of Set 9 | addis zemen
# City not found. skipping...
# Processing Record 29 of Set 9 | zhangjiakou
# Processing Record 30 of Set 9 | alyangula
# Processing Record 31 of Set 9 | parrita
# Processing Record 32 of Set 9 | valdivia
# Processing Record 33 of Set 9 | tambura
# Processing Record 34 of Set 9 | dhidhdhoo
# Processing Record 35 of Set 9 | bethanien
# Processing Record 36 of Set 9 | broome
# Processing Record 37 of Set 9 | vanavara
# Processing Record 38 of Set 9 | lasa
# Processing Record 39 of Set 9 | yanan
# City not found. skipping...
# Processing Record 40 of Set 9 | hasaki
# Processing Record 41 of Set 9 | rio gallegos
# Processing Record 42 of Set 9 | disna
# Processing Record 43 of Set 9 | halalo
# City not found. skipping...
# Processing Record 44 of Set 9 | jardim
# Processing Record 45 of Set 9 | leh
# Processing Record 46 of Set 9 | puerto escondido
# Processing Record 47 of Set 9 | tawkar
# City not found. skipping...
# Processing Record 48 of Set 9 | airai
# Processing Record 49 of Set 9 | umm kaddadah
# Processing Record 50 of Set 9 | bathsheba
# Processing Record 1 of Set 10 | mithi
# Processing Record 2 of Set 10 | waipawa
# Processing Record 3 of Set 10 | vikulovo
# Processing Record 4 of Set 10 | jonkoping
# Processing Record 5 of Set 10 | chunoyar
# Processing Record 6 of Set 10 | eirunepe
# Processing Record 7 of Set 10 | krasnyy profintern
# Processing Record 8 of Set 10 | sosnovo-ozerskoye
# Processing Record 9 of Set 10 | bay roberts
# Processing Record 10 of Set 10 | juneau
# Processing Record 11 of Set 10 | tupik
# Processing Record 12 of Set 10 | vila praia de ancora
# Processing Record 13 of Set 10 | jiangyou
# Processing Record 14 of Set 10 | baffa
# Processing Record 15 of Set 10 | north augusta
# Processing Record 16 of Set 10 | yirol
# City not found. skipping...
# Processing Record 17 of Set 10 | rancho palos verdes
# Processing Record 18 of Set 10 | illoqqortoormiut
# City not found. skipping...
# Processing Record 19 of Set 10 | chester
# Processing Record 20 of Set 10 | puerto leguizamo
# Processing Record 21 of Set 10 | ust-nera
# Processing Record 22 of Set 10 | helong
# Processing Record 23 of Set 10 | starodub
# Processing Record 24 of Set 10 | hastings
# Processing Record 25 of Set 10 | koungou
# Processing Record 26 of Set 10 | pokosnoye
# Processing Record 27 of Set 10 | chiang klang
# Processing Record 28 of Set 10 | preobrazheniye
# Processing Record 29 of Set 10 | grandola
# Processing Record 30 of Set 10 | half moon bay
# Processing Record 31 of Set 10 | ust-karsk
# Processing Record 32 of Set 10 | gazli
# Processing Record 33 of Set 10 | guayaramerin
# Processing Record 34 of Set 10 | cedar city
# Processing Record 35 of Set 10 | la serena
# Processing Record 36 of Set 10 | sentyabrskiy
# City not found. skipping...
# Processing Record 37 of Set 10 | cockburn town
# Processing Record 38 of Set 10 | dalian
# Processing Record 39 of Set 10 | san ignacio
# Processing Record 40 of Set 10 | ryotsu
# Processing Record 41 of Set 10 | yarmolyntsi
# Processing Record 42 of Set 10 | waiouru
# Processing Record 43 of Set 10 | kandrian
# Processing Record 44 of Set 10 | saint anthony
# Processing Record 45 of Set 10 | ewa beach
# Processing Record 46 of Set 10 | palana
# Processing Record 47 of Set 10 | chokurdakh
# Processing Record 48 of Set 10 | salalah
# Processing Record 49 of Set 10 | tomigusuku
# Processing Record 50 of Set 10 | college
# Processing Record 1 of Set 11 | general roca
# Processing Record 2 of Set 11 | axixa do tocantins
# City not found. skipping...
# Processing Record 3 of Set 11 | marawi
# Processing Record 4 of Set 11 | inhambane
# Processing Record 5 of Set 11 | lucapa
# Processing Record 6 of Set 11 | nelson
# Processing Record 7 of Set 11 | matagami
# Processing Record 8 of Set 11 | muli
# Processing Record 9 of Set 11 | puerto del rosario
# Processing Record 10 of Set 11 | gdov
# Processing Record 11 of Set 11 | port blair
# Processing Record 12 of Set 11 | mucurapo
# Processing Record 13 of Set 11 | sam phran
# Processing Record 14 of Set 11 | ketchikan
# Processing Record 15 of Set 11 | biloela
# Processing Record 16 of Set 11 | qurayyat
# Processing Record 17 of Set 11 | antofagasta
# Processing Record 18 of Set 11 | povenets
# Processing Record 19 of Set 11 | honningsvag
# Processing Record 20 of Set 11 | wichita falls
# Processing Record 21 of Set 11 | viligili
# City not found. skipping...
# Processing Record 22 of Set 11 | usinsk
# Processing Record 23 of Set 11 | launceston
# Processing Record 24 of Set 11 | bredy
# Processing Record 25 of Set 11 | muros
# Processing Record 26 of Set 11 | manokwari
# Processing Record 27 of Set 11 | sioux lookout
# Processing Record 28 of Set 11 | ciras
# City not found. skipping...
# Processing Record 29 of Set 11 | sangar
# Processing Record 30 of Set 11 | sabang
# Processing Record 31 of Set 11 | mrirt
# City not found. skipping...
# Processing Record 32 of Set 11 | eyrarbakki
# Processing Record 33 of Set 11 | channel-port aux basques
# Processing Record 34 of Set 11 | talaya
# Processing Record 35 of Set 11 | coquimbo
# Processing Record 36 of Set 11 | samusu
# City not found. skipping...
# Processing Record 37 of Set 11 | kashi
# Processing Record 38 of Set 11 | sao jose do rio pardo
# Processing Record 39 of Set 11 | oriximina
# Processing Record 40 of Set 11 | omutinskoye
# City not found. skipping...
# Processing Record 41 of Set 11 | mouzakion
# City not found. skipping...
# Processing Record 42 of Set 11 | quibdo
# Processing Record 43 of Set 11 | henties bay
# Processing Record 44 of Set 11 | lata
# Processing Record 45 of Set 11 | larsnes
# Processing Record 46 of Set 11 | palauig
# Processing Record 47 of Set 11 | bam
# Processing Record 48 of Set 11 | namatanai
# Processing Record 49 of Set 11 | kabare
# Processing Record 50 of Set 11 | rocha
# Processing Record 1 of Set 12 | padang
# Processing Record 2 of Set 12 | lao cai
# Processing Record 3 of Set 12 | kahului
# Processing Record 4 of Set 12 | phrai bung
# City not found. skipping...
# Processing Record 5 of Set 12 | barda
# Processing Record 6 of Set 12 | plettenberg bay
# Processing Record 7 of Set 12 | sao filipe
# Processing Record 8 of Set 12 | vila
# Processing Record 9 of Set 12 | rosario oeste
# Processing Record 10 of Set 12 | tautira
# Processing Record 11 of Set 12 | buqayq
# City not found. skipping...
# Processing Record 12 of Set 12 | san patricio
# Processing Record 13 of Set 12 | skibbereen
# Processing Record 14 of Set 12 | okhotsk
# Processing Record 15 of Set 12 | bushehr
# Processing Record 16 of Set 12 | volkach
# Processing Record 17 of Set 12 | mendahara
# City not found. skipping...
# Processing Record 18 of Set 12 | anadyr
# Processing Record 19 of Set 12 | adelaide
# Processing Record 20 of Set 12 | canakkale
# Processing Record 21 of Set 12 | beloha
# Processing Record 22 of Set 12 | tigzirt
# Processing Record 23 of Set 12 | ust-ilimsk
# Processing Record 24 of Set 12 | marystown
# Processing Record 25 of Set 12 | northport
# Processing Record 26 of Set 12 | bindura
# Processing Record 27 of Set 12 | scottsbluff
# Processing Record 28 of Set 12 | portland
# Processing Record 29 of Set 12 | kutulik
# Processing Record 30 of Set 12 | imbituba
# Processing Record 31 of Set 12 | solnechnyy
# Processing Record 32 of Set 12 | bambanglipuro
# Processing Record 33 of Set 12 | sungaipenuh
# Processing Record 34 of Set 12 | salinopolis
# Processing Record 35 of Set 12 | bourail
# Processing Record 36 of Set 12 | trelew
# Processing Record 37 of Set 12 | hami
# Processing Record 38 of Set 12 | cap malheureux
# Processing Record 39 of Set 12 | walvis bay
# Processing Record 40 of Set 12 | haibowan
# City not found. skipping...
# Processing Record 41 of Set 12 | honiara
# Processing Record 42 of Set 12 | zhanaozen
# Processing Record 43 of Set 12 | burgos
# Processing Record 44 of Set 12 | wajima
# Processing Record 45 of Set 12 | otautau
# Processing Record 46 of Set 12 | watsa
# Processing Record 47 of Set 12 | yerbogachen
# Processing Record 48 of Set 12 | the valley
# Processing Record 49 of Set 12 | shenjiamen
# Processing Record 50 of Set 12 | saint-denis
# Processing Record 1 of Set 13 | pringsewu
# Processing Record 2 of Set 13 | bolshaya murta
# City not found. skipping...
# Processing Record 3 of Set 13 | kuytun
# Processing Record 4 of Set 13 | havelock
# Processing Record 5 of Set 13 | rio grande
# Processing Record 6 of Set 13 | guaruja
# Processing Record 7 of Set 13 | ndele
# Processing Record 8 of Set 13 | verkhnetulomskiy
# Processing Record 9 of Set 13 | la ronge
# Processing Record 10 of Set 13 | mkushi
# Processing Record 11 of Set 13 | nautla
# Processing Record 12 of Set 13 | maceio
# Processing Record 13 of Set 13 | sinnamary
# Processing Record 14 of Set 13 | yuryevets
# Processing Record 15 of Set 13 | firovo
# Processing Record 16 of Set 13 | sao miguel do araguaia
# Processing Record 17 of Set 13 | kalmanka
# Processing Record 18 of Set 13 | kindu
# Processing Record 19 of Set 13 | pangnirtung
# Processing Record 20 of Set 13 | zhangye
# Processing Record 21 of Set 13 | halifax
# Processing Record 22 of Set 13 | krutinka
# Processing Record 23 of Set 13 | nizhneyansk
# City not found. skipping...
# Processing Record 24 of Set 13 | salto
# Processing Record 25 of Set 13 | matadi
# Processing Record 26 of Set 13 | carballo
# Processing Record 27 of Set 13 | wanaka
# Processing Record 28 of Set 13 | saint-augustin
# Processing Record 29 of Set 13 | karousades
# City not found. skipping...
# Processing Record 30 of Set 13 | los llanos de aridane
# Processing Record 31 of Set 13 | ust-maya
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | kharp
# Processing Record 34 of Set 13 | liverpool
# Processing Record 35 of Set 13 | orlik
# Processing Record 36 of Set 13 | klyuchevskiy
# Processing Record 37 of Set 13 | sibolga
# Processing Record 38 of Set 13 | bacungan
# Processing Record 39 of Set 13 | zyryanka
# Processing Record 40 of Set 13 | champerico
# Processing Record 41 of Set 13 | yenagoa
# Processing Record 42 of Set 13 | antalaha
# Processing Record 43 of Set 13 | barawe
# City not found. skipping...
# Processing Record 44 of Set 13 | bismarck
# Processing Record 45 of Set 13 | nuevo progreso
# Processing Record 46 of Set 13 | port hedland
# Processing Record 47 of Set 13 | jalapa
# Processing Record 48 of Set 13 | riverton
# Processing Record 49 of Set 13 | asau
# Processing Record 50 of Set 13 | jiuquan
# Processing Record 1 of Set 14 | sampit
# Processing Record 2 of Set 14 | kuche
# City not found. skipping...
# Processing Record 3 of Set 14 | eldikan
# City not found. skipping...
# Processing Record 4 of Set 14 | lunavada
# Processing Record 5 of Set 14 | todos santos
# Processing Record 6 of Set 14 | tual
# Processing Record 7 of Set 14 | pacific grove
# Processing Record 8 of Set 14 | beira
# Processing Record 9 of Set 14 | maningrida
# Processing Record 10 of Set 14 | quatre cocos
# Processing Record 11 of Set 14 | kropotkin
# Processing Record 12 of Set 14 | vysokogornyy
# Processing Record 13 of Set 14 | marienburg
# Processing Record 14 of Set 14 | sorvag
# City not found. skipping...
# Processing Record 15 of Set 14 | shingu
# Processing Record 16 of Set 14 | landeck
# Processing Record 17 of Set 14 | mackay
# Processing Record 18 of Set 14 | xihe
# Processing Record 19 of Set 14 | newport
# Processing Record 20 of Set 14 | pierre
# Processing Record 21 of Set 14 | manzhouli
# Processing Record 22 of Set 14 | margate
# Processing Record 23 of Set 14 | omboue
# Processing Record 24 of Set 14 | toktogul
# Processing Record 25 of Set 14 | doha
# Processing Record 26 of Set 14 | xining
# Processing Record 27 of Set 14 | dalvik
# Processing Record 28 of Set 14 | xuanhua
# Processing Record 29 of Set 14 | lethem
# Processing Record 30 of Set 14 | puerto narino
# Processing Record 31 of Set 14 | santa cruz
# Processing Record 32 of Set 14 | saint-jean-port-joli
# Processing Record 33 of Set 14 | laureles
# Processing Record 34 of Set 14 | maldonado
# Processing Record 35 of Set 14 | belyy yar
# Processing Record 36 of Set 14 | mbanza-ngungu
# Processing Record 37 of Set 14 | san jose
# Processing Record 38 of Set 14 | port moresby
# Processing Record 39 of Set 14 | miramar
# Processing Record 40 of Set 14 | surt
# Processing Record 41 of Set 14 | ostrovnoy
# Processing Record 42 of Set 14 | worthington
# Processing Record 43 of Set 14 | beian
# Processing Record 44 of Set 14 | melenki
# Processing Record 45 of Set 14 | verkhnevilyuysk
# Processing Record 46 of Set 14 | fukue
# Processing Record 47 of Set 14 | mantua
# Processing Record 48 of Set 14 | amapa
# Processing Record 49 of Set 14 | nurota
# Processing Record 50 of Set 14 | along
# Processing Record 1 of Set 15 | kaeo
# Processing Record 2 of Set 15 | saint-louis
# Processing Record 3 of Set 15 | dera bugti
# Processing Record 4 of Set 15 | moskovskiy
# Processing Record 5 of Set 15 | quincy
# Processing Record 6 of Set 15 | bulls
# Processing Record 7 of Set 15 | luderitz
# Processing Record 8 of Set 15 | kutum
# Processing Record 9 of Set 15 | bosaso
# Processing Record 10 of Set 15 | abu kamal
# Processing Record 11 of Set 15 | ucluelet
# Processing Record 12 of Set 15 | gamba
# Processing Record 13 of Set 15 | madison
# Processing Record 14 of Set 15 | luwuk
# Processing Record 15 of Set 15 | sovetskiy
# Processing Record 16 of Set 15 | tuggurt
# City not found. skipping...
# Processing Record 17 of Set 15 | kirakira
# Processing Record 18 of Set 15 | srandakan
# Processing Record 19 of Set 15 | udachnyy
# Processing Record 20 of Set 15 | harper
# Processing Record 21 of Set 15 | qianan
# Processing Record 22 of Set 15 | tazovskiy
# Processing Record 23 of Set 15 | erenhot
# Processing Record 24 of Set 15 | palaiokhora
# City not found. skipping...
# Processing Record 25 of Set 15 | toamasina
# Processing Record 26 of Set 15 | biak
# Processing Record 27 of Set 15 | aswan
# Processing Record 28 of Set 15 | afmadu
# City not found. skipping...
# Processing Record 29 of Set 15 | waspan
# Processing Record 30 of Set 15 | gumrak
# Processing Record 31 of Set 15 | duku
# Processing Record 32 of Set 15 | itarema
# Processing Record 33 of Set 15 | porto santo
# Processing Record 34 of Set 15 | satipo
# Processing Record 35 of Set 15 | port lavaca
# Processing Record 36 of Set 15 | carman
# Processing Record 37 of Set 15 | simbahan
# Processing Record 38 of Set 15 | bardiyah
# Processing Record 39 of Set 15 | flinders
# Processing Record 40 of Set 15 | elizabeth city
# Processing Record 41 of Set 15 | kendari
# Processing Record 42 of Set 15 | whyalla
# Processing Record 43 of Set 15 | hvide sande
# Processing Record 44 of Set 15 | batagay-alyta
# Processing Record 45 of Set 15 | plouzane
# Processing Record 46 of Set 15 | fare
# Processing Record 47 of Set 15 | ulaanbaatar
# Processing Record 48 of Set 15 | inta
# Processing Record 49 of Set 15 | sola
# Processing Record 50 of Set 15 | alekseyevka
# Processing Record 1 of Set 16 | mbour
# Processing Record 2 of Set 16 | kulunda
# Processing Record 3 of Set 16 | gawler
# Processing Record 4 of Set 16 | otavi
# Processing Record 5 of Set 16 | bontang
# Processing Record 6 of Set 16 | felsoszentivan
# Processing Record 7 of Set 16 | nueva rosita
# Processing Record 8 of Set 16 | hongan
# City not found. skipping...
# Processing Record 9 of Set 16 | sur
# Processing Record 10 of Set 16 | otorohanga
# Processing Record 11 of Set 16 | abapo
# Processing Record 12 of Set 16 | kuusamo
# Processing Record 13 of Set 16 | milton
# Processing Record 14 of Set 16 | miri
# Processing Record 15 of Set 16 | richards bay
# Processing Record 16 of Set 16 | dolinsk
# Processing Record 17 of Set 16 | ramanuj ganj
# Processing Record 18 of Set 16 | pyinmana
# Processing Record 19 of Set 16 | mokhsogollokh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 702

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tumpat   6.1978  102.1710     78.78        83          20
# 1    Constitucion -35.3333  -72.4167     63.48        65          18
# 2      Wellington -41.2866  174.7756     50.58        97         100
# 3  Saint-Philippe -21.3585   55.7679     67.59        78          44
# 4       Tuatapere -46.1333  167.6833     35.46        94          45
# 5    Punta Arenas -53.1500  -70.9167     48.31        43          20
# 6         Manggar  -2.8833  108.2667     78.40        85         100
# 7     Pietarsaari  63.6500   22.6833     45.90        90         100
# 8           Vaini -21.2000 -175.2000     73.56        78          75
# 9          Ripoll  42.2006    2.1903     62.58        77           2
#
#    Wind Speed Country   Current Description
# 0        2.30      MY            few clouds
# 1        2.37      CL            few clouds
# 2       27.63      NZ            light rain
# 3       11.72      RE      scattered clouds
# 4        3.85      NZ      scattered clouds
# 5       25.32      CL            few clouds
# 6        5.50      ID  heavy intensity rain
# 7       12.30      FI       overcast clouds
# 8        8.05      TO         broken clouds
# 9        1.01      ES             clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
print(city_data_df)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Tumpat      MY   6.1978  102.1710     78.78        83
# 1      Constitucion      CL -35.3333  -72.4167     63.48        65
# 2        Wellington      NZ -41.2866  174.7756     50.58        97
# 3    Saint-Philippe      RE -21.3585   55.7679     67.59        78
# 4         Tuatapere      NZ -46.1333  167.6833     35.46        94
# ..              ...     ...      ...       ...       ...       ...
# 697    Richards Bay      ZA -28.7830   32.0377     70.36        82
# 698         Dolinsk      RU  47.3500  142.8000     46.74        82
# 699    Ramanuj Ganj      IN  23.8000   83.7000     74.16        77
# 700        Pyinmana      MM  19.7333   96.2167     74.55        97
# 701   Mokhsogollokh      RU  61.4681  128.9203     22.03        73
#
#      Cloudiness  Wind Speed Current Description
# 0            20        2.30          few clouds
# 1            18        2.37          few clouds
# 2           100       27.63          light rain
# 3            44       11.72    scattered clouds
# 4            45        3.85    scattered clouds
# ..          ...         ...                 ...
# 697         100       14.85     overcast clouds
# 698          89        5.26     overcast clouds
# 699          84        2.08       broken clouds
# 700         100        3.04     overcast clouds
# 701         100        4.81     overcast clouds
#
# [702 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
